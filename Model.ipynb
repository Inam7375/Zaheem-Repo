# %%
import numpy as np
import pandas as pd
import os
import itertools
import os, stat, time
from os.path import dirname as up
import shutil
from PIL import Image
import tqdm
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import cv2

from sklearn.model_selection import train_test_split
from tensorflow.keras.utils import to_categorical

from tensorflow.keras import Sequential
from tensorflow.keras.optimizers import SGD, RMSprop, Adam, Adagrad, Adadelta
from keras.layers import Dense, Dropout, Activation, Flatten, BatchNormalization, Conv2D, MaxPool2D, MaxPooling2D
from tensorflow.keras.callbacks import EarlyStopping

# %%
import numpy as np
import pandas as pd
from tqdm import tqdm

base = 'Data/'

ids = os.listdir(base)
data = []
for id in tqdm(ids):
  try:
    files1 = os.listdir(base + id + '/1/')
    files0 = os.listdir(base + id + '/0/')
    for x in files1:
      data.append(base + id + '/1/' + x)
    for x in files0:
      data.append(base + id + '/0/' + x)
  except:
    FileNotFoundError
len(data)
# Out:
# 100%|██████████| 279/279 [00:01<00:00, 276.24it/s]
# 277524

# %%
import random

random.shuffle(data)
data = data[:20000]
len(data)
# Out:
# 20000

# %%
import cv2
from tqdm import tqdm
import keras_preprocessing.image as IMAGE
from PIL import Image

images=[]
labels=[]

for i in tqdm(data):
  label = int(i[-5])
  img = IMAGE.img_to_array(IMAGE.load_img(i, target_size=(50, 50)))
  images.append(img)
  labels.append(label)
# Out:
# 100%|██████████| 20000/20000 [11:56<00:00, 29.36it/s]

# %%
from sklearn.model_selection import train_test_split

y = np.array(labels)
x = np.stack(images)/255

x_train,x_test,y_train,y_test = train_test_split(x, y, random_state=0, test_size=0.3)
print(x_train.shape, x_test.shape, y_train.shape, y_test.shape)
# Out:
# (14000, 50, 50, 3) (6000, 50, 50, 3) (14000,) (6000,)

# %%
model=Sequential()

model.add(Conv2D(filters=32,kernel_size=(4,4),input_shape=(50,50,3),activation='relu'))
model.add(MaxPool2D(pool_size=(2,2)))
model.add(MaxPool2D(pool_size=(2,2)))
model.add(Dropout(0.25))
model.add(Conv2D(filters=32,kernel_size=(4,4),activation='relu'))
model.add(MaxPool2D(pool_size=(2,2)))
model.add(MaxPool2D(pool_size=(2,2), strides=(2,2)))
model.add(Dropout(0.25))
model.add(Flatten())
model.add(Dense(64,activation='relu'))
model.add(Dense(1,activation='sigmoid'))
model.compile(loss = 'binary_crossentropy', optimizer ='adam', metrics= ['accuracy'])

# model.summary()

# %%
import tensorflow as tf

history = model.fit(x_train, y_train, validation_data = (x_test, y_test), epochs = 100, verbose = 2, batch_size = 256)
# Out:
# Epoch 1/100
# 55/55 - 38s - loss: 0.5731 - accuracy: 0.6993 - val_loss: 0.5937 - val_accuracy: 0.7880
# Epoch 2/100
# 55/55 - 36s - loss: 0.4758 - accuracy: 0.7779 - val_loss: 0.4555 - val_accuracy: 0.8052
# Epoch 3/100
# 55/55 - 36s - loss: 0.4408 - accuracy: 0.8057 - val_loss: 0.4377 - val_accuracy: 0.8268
# Epoch 4/100
# 55/55 - 36s - loss: 0.4242 - accuracy: 0.8116 - val_loss: 0.4056 - val_accuracy: 0.8253
# Epoch 5/100
# 55/55 - 36s - loss: 0.4271 - accuracy: 0.8103 - val_loss: 0.4027 - val_accuracy: 0.8295
# Epoch 6/100
# 55/55 - 36s - loss: 0.4147 - accuracy: 0.8212 - val_loss: 0.4470 - val_accuracy: 0.8068
# Epoch 7/100
# 55/55 - 35s - loss: 0.4081 - accuracy: 0.8233 - val_loss: 0.4259 - val_accuracy: 0.8182
# Epoch 8/100
# 55/55 - 36s - loss: 0.4098 - accuracy: 0.8201 - val_loss: 0.4581 - val_accuracy: 0.7950
# Epoch 9/100
# 55/55 - 35s - loss: 0.4072 - accuracy: 0.8231 - val_loss: 0.4260 - val_accuracy: 0.8098
# Epoch 10/100
# 55/55 - 36s - loss: 0.4086 - accuracy: 0.8234 - val_loss: 0.4082 - val_accuracy: 0.8327
# Epoch 11/100
# 55/55 - 34s - loss: 0.4034 - accuracy: 0.8254 - val_loss: 0.4151 - val_accuracy: 0.8217
# Epoch 12/100
# 55/55 - 36s - loss: 0.4067 - accuracy: 0.8266 - val_loss: 0.3941 - val_accuracy: 0.8365
# Epoch 13/100
# 55/55 - 35s - loss: 0.3997 - accuracy: 0.8291 - val_loss: 0.4012 - val_accuracy: 0.8293
# Epoch 14/100
# 55/55 - 36s - loss: 0.4030 - accuracy: 0.8250 - val_loss: 0.4195 - val_accuracy: 0.8272
# Epoch 15/100
# 55/55 - 35s - loss: 0.3963 - accuracy: 0.8276 - val_loss: 0.4016 - val_accuracy: 0.8288
# Epoch 16/100
# 55/55 - 36s - loss: 0.3935 - accuracy: 0.8299 - val_loss: 0.4091 - val_accuracy: 0.8307
# Epoch 17/100
# 55/55 - 36s - loss: 0.3925 - accuracy: 0.8307 - val_loss: 0.3790 - val_accuracy: 0.8388
# Epoch 18/100
# 55/55 - 36s - loss: 0.3911 - accuracy: 0.8306 - val_loss: 0.4071 - val_accuracy: 0.8273
# Epoch 19/100
# 55/55 - 38s - loss: 0.3876 - accuracy: 0.8337 - val_loss: 0.3764 - val_accuracy: 0.8402
# Epoch 20/100
# 55/55 - 37s - loss: 0.3937 - accuracy: 0.8294 - val_loss: 0.3858 - val_accuracy: 0.8403
# Epoch 21/100
# 55/55 - 36s - loss: 0.3944 - accuracy: 0.8311 - val_loss: 0.3850 - val_accuracy: 0.8423
# Epoch 22/100
# 55/55 - 35s - loss: 0.3968 - accuracy: 0.8300 - val_loss: 0.3925 - val_accuracy: 0.8417
# Epoch 23/100
# 55/55 - 36s - loss: 0.3856 - accuracy: 0.8335 - val_loss: 0.4082 - val_accuracy: 0.8347
# Epoch 24/100
# 55/55 - 36s - loss: 0.3793 - accuracy: 0.8369 - val_loss: 0.4689 - val_accuracy: 0.7857
# Epoch 25/100
# 55/55 - 36s - loss: 0.3818 - accuracy: 0.8378 - val_loss: 0.3845 - val_accuracy: 0.8395
# Epoch 26/100
# 55/55 - 37s - loss: 0.3785 - accuracy: 0.8381 - val_loss: 0.3757 - val_accuracy: 0.8425
# Epoch 27/100
# 55/55 - 39s - loss: 0.3762 - accuracy: 0.8391 - val_loss: 0.3890 - val_accuracy: 0.8393
# Epoch 28/100
# 55/55 - 36s - loss: 0.3760 - accuracy: 0.8374 - val_loss: 0.3746 - val_accuracy: 0.8403
# Epoch 29/100
# 55/55 - 35s - loss: 0.3728 - accuracy: 0.8417 - val_loss: 0.3996 - val_accuracy: 0.8330
# Epoch 30/100
# 55/55 - 36s - loss: 0.3723 - accuracy: 0.8412 - val_loss: 0.4119 - val_accuracy: 0.8223
# Epoch 31/100
# 55/55 - 35s - loss: 0.3730 - accuracy: 0.8412 - val_loss: 0.4099 - val_accuracy: 0.8328
# Epoch 32/100
# 55/55 - 36s - loss: 0.3708 - accuracy: 0.8414 - val_loss: 0.3988 - val_accuracy: 0.8327
# Epoch 33/100
# 55/55 - 35s - loss: 0.3707 - accuracy: 0.8440 - val_loss: 0.4009 - val_accuracy: 0.8382
# Epoch 34/100
# 55/55 - 36s - loss: 0.3728 - accuracy: 0.8426 - val_loss: 0.4171 - val_accuracy: 0.8348
# Epoch 35/100
# 55/55 - 36s - loss: 0.3723 - accuracy: 0.8411 - val_loss: 0.3921 - val_accuracy: 0.8408
# Epoch 36/100
# 55/55 - 36s - loss: 0.3675 - accuracy: 0.8440 - val_loss: 0.3680 - val_accuracy: 0.8423
# Epoch 37/100
# 55/55 - 35s - loss: 0.3708 - accuracy: 0.8429 - val_loss: 0.3762 - val_accuracy: 0.8485
# Epoch 38/100
# 55/55 - 35s - loss: 0.3656 - accuracy: 0.8436 - val_loss: 0.3820 - val_accuracy: 0.8353
# Epoch 39/100
# 55/55 - 36s - loss: 0.3675 - accuracy: 0.8424 - val_loss: 0.3940 - val_accuracy: 0.8317
# Epoch 40/100
# 55/55 - 35s - loss: 0.3642 - accuracy: 0.8446 - val_loss: 0.3771 - val_accuracy: 0.8430
# Epoch 41/100
# 55/55 - 36s - loss: 0.3629 - accuracy: 0.8461 - val_loss: 0.3834 - val_accuracy: 0.8430
# Epoch 42/100
# 55/55 - 35s - loss: 0.3648 - accuracy: 0.8441 - val_loss: 0.3571 - val_accuracy: 0.8472
# Epoch 43/100
# 55/55 - 36s - loss: 0.3618 - accuracy: 0.8458 - val_loss: 0.3922 - val_accuracy: 0.8353
# Epoch 44/100
# 55/55 - 35s - loss: 0.3662 - accuracy: 0.8473 - val_loss: 0.3828 - val_accuracy: 0.8400
# Epoch 45/100
# 55/55 - 36s - loss: 0.3672 - accuracy: 0.8449 - val_loss: 0.3744 - val_accuracy: 0.8440
# Epoch 46/100
# 55/55 - 35s - loss: 0.3677 - accuracy: 0.8432 - val_loss: 0.3672 - val_accuracy: 0.8455
# Epoch 47/100
# 55/55 - 35s - loss: 0.3619 - accuracy: 0.8485 - val_loss: 0.3629 - val_accuracy: 0.8478
# Epoch 48/100
# 55/55 - 35s - loss: 0.3638 - accuracy: 0.8454 - val_loss: 0.3789 - val_accuracy: 0.8425
# Epoch 49/100
# 55/55 - 36s - loss: 0.3574 - accuracy: 0.8496 - val_loss: 0.4018 - val_accuracy: 0.8313
# Epoch 50/100
# 55/55 - 35s - loss: 0.3653 - accuracy: 0.8448 - val_loss: 0.4213 - val_accuracy: 0.8217
# Epoch 51/100
# 55/55 - 35s - loss: 0.3657 - accuracy: 0.8440 - val_loss: 0.3849 - val_accuracy: 0.8395
# Epoch 52/100
# 55/55 - 35s - loss: 0.3614 - accuracy: 0.8467 - val_loss: 0.3600 - val_accuracy: 0.8490
# Epoch 53/100
# 55/55 - 35s - loss: 0.3586 - accuracy: 0.8460 - val_loss: 0.3663 - val_accuracy: 0.8453
# Epoch 54/100
# 55/55 - 35s - loss: 0.3560 - accuracy: 0.8495 - val_loss: 0.3909 - val_accuracy: 0.8342
# Epoch 55/100
# 55/55 - 35s - loss: 0.3493 - accuracy: 0.8513 - val_loss: 0.3607 - val_accuracy: 0.8493
# Epoch 56/100
# 55/55 - 36s - loss: 0.3476 - accuracy: 0.8519 - val_loss: 0.3732 - val_accuracy: 0.8445
# Epoch 57/100
# 55/55 - 35s - loss: 0.3536 - accuracy: 0.8517 - val_loss: 0.3657 - val_accuracy: 0.8458
# Epoch 58/100
# 55/55 - 36s - loss: 0.3505 - accuracy: 0.8520 - val_loss: 0.3553 - val_accuracy: 0.8487
# Epoch 59/100
# 55/55 - 35s - loss: 0.3524 - accuracy: 0.8484 - val_loss: 0.3620 - val_accuracy: 0.8487
# Epoch 60/100
# 55/55 - 36s - loss: 0.3464 - accuracy: 0.8553 - val_loss: 0.3532 - val_accuracy: 0.8517
# Epoch 61/100
# 55/55 - 35s - loss: 0.3511 - accuracy: 0.8517 - val_loss: 0.3746 - val_accuracy: 0.8427
# Epoch 62/100
# 55/55 - 36s - loss: 0.3508 - accuracy: 0.8525 - val_loss: 0.4022 - val_accuracy: 0.8237
# Epoch 63/100
# 55/55 - 35s - loss: 0.3484 - accuracy: 0.8534 - val_loss: 0.3708 - val_accuracy: 0.8443
# Epoch 64/100
# 55/55 - 36s - loss: 0.3473 - accuracy: 0.8520 - val_loss: 0.3968 - val_accuracy: 0.8297
# Epoch 65/100
# 55/55 - 36s - loss: 0.3502 - accuracy: 0.8519 - val_loss: 0.3559 - val_accuracy: 0.8497
# Epoch 66/100
# 55/55 - 35s - loss: 0.3506 - accuracy: 0.8517 - val_loss: 0.3598 - val_accuracy: 0.8502
# Epoch 67/100
# 55/55 - 39s - loss: 0.3430 - accuracy: 0.8524 - val_loss: 0.3971 - val_accuracy: 0.8260
# Epoch 68/100
# 55/55 - 44s - loss: 0.3445 - accuracy: 0.8547 - val_loss: 0.3718 - val_accuracy: 0.8440
# Epoch 69/100
# 55/55 - 40s - loss: 0.3511 - accuracy: 0.8499 - val_loss: 0.3556 - val_accuracy: 0.8512
# Epoch 70/100
# 55/55 - 37s - loss: 0.3477 - accuracy: 0.8526 - val_loss: 0.3867 - val_accuracy: 0.8345
# Epoch 71/100
# 55/55 - 36s - loss: 0.3512 - accuracy: 0.8493 - val_loss: 0.4240 - val_accuracy: 0.8063
# Epoch 72/100
# 55/55 - 36s - loss: 0.3458 - accuracy: 0.8536 - val_loss: 0.3452 - val_accuracy: 0.8505
# Epoch 73/100
# 55/55 - 36s - loss: 0.3437 - accuracy: 0.8524 - val_loss: 0.3605 - val_accuracy: 0.8502
# Epoch 74/100
# 55/55 - 37s - loss: 0.3388 - accuracy: 0.8562 - val_loss: 0.3530 - val_accuracy: 0.8497
# Epoch 75/100
# 55/55 - 36s - loss: 0.3345 - accuracy: 0.8561 - val_loss: 0.3528 - val_accuracy: 0.8510
# Epoch 76/100
# 55/55 - 37s - loss: 0.3325 - accuracy: 0.8591 - val_loss: 0.3531 - val_accuracy: 0.8507
# Epoch 77/100
# 55/55 - 39s - loss: 0.3444 - accuracy: 0.8541 - val_loss: 0.4056 - val_accuracy: 0.8200
# Epoch 78/100
# 55/55 - 37s - loss: 0.3446 - accuracy: 0.8526 - val_loss: 0.3684 - val_accuracy: 0.8450
# Epoch 79/100
# 55/55 - 37s - loss: 0.3360 - accuracy: 0.8534 - val_loss: 0.3516 - val_accuracy: 0.8485
# Epoch 80/100
# 55/55 - 35s - loss: 0.3331 - accuracy: 0.8583 - val_loss: 0.3594 - val_accuracy: 0.8438
# Epoch 81/100
# 55/55 - 37s - loss: 0.3346 - accuracy: 0.8600 - val_loss: 0.3462 - val_accuracy: 0.8528
# Epoch 82/100
# 55/55 - 36s - loss: 0.3332 - accuracy: 0.8586 - val_loss: 0.3750 - val_accuracy: 0.8335
# Epoch 83/100
# 55/55 - 37s - loss: 0.3372 - accuracy: 0.8592 - val_loss: 0.3528 - val_accuracy: 0.8490
# Epoch 84/100
# 55/55 - 36s - loss: 0.3338 - accuracy: 0.8581 - val_loss: 0.3753 - val_accuracy: 0.8400
# Epoch 85/100
# 55/55 - 37s - loss: 0.3365 - accuracy: 0.8582 - val_loss: 0.3923 - val_accuracy: 0.8318
# Epoch 86/100
# 55/55 - 37s - loss: 0.3313 - accuracy: 0.8609 - val_loss: 0.3618 - val_accuracy: 0.8402
# Epoch 87/100
# 55/55 - 37s - loss: 0.3370 - accuracy: 0.8584 - val_loss: 0.3447 - val_accuracy: 0.8530
# Epoch 88/100
# 55/55 - 37s - loss: 0.3344 - accuracy: 0.8591 - val_loss: 0.3759 - val_accuracy: 0.8370
# Epoch 89/100
# 55/55 - 36s - loss: 0.3362 - accuracy: 0.8596 - val_loss: 0.3564 - val_accuracy: 0.8492
# Epoch 90/100
# 55/55 - 36s - loss: 0.3345 - accuracy: 0.8582 - val_loss: 0.3867 - val_accuracy: 0.8420
# Epoch 91/100
# 55/55 - 36s - loss: 0.3365 - accuracy: 0.8573 - val_loss: 0.3567 - val_accuracy: 0.8498
# Epoch 92/100
# 55/55 - 37s - loss: 0.3405 - accuracy: 0.8559 - val_loss: 0.3515 - val_accuracy: 0.8538
# Epoch 93/100
# 55/55 - 36s - loss: 0.3315 - accuracy: 0.8584 - val_loss: 0.3777 - val_accuracy: 0.8368
# Epoch 94/100
# 55/55 - 37s - loss: 0.3286 - accuracy: 0.8621 - val_loss: 0.3567 - val_accuracy: 0.8490
# Epoch 95/100
# 55/55 - 35s - loss: 0.3333 - accuracy: 0.8596 - val_loss: 0.3730 - val_accuracy: 0.8380
# Epoch 96/100
# 55/55 - 36s - loss: 0.3330 - accuracy: 0.8592 - val_loss: 0.3501 - val_accuracy: 0.8510
# Epoch 97/100
# 55/55 - 35s - loss: 0.3257 - accuracy: 0.8641 - val_loss: 0.3464 - val_accuracy: 0.8540
# Epoch 98/100
# 55/55 - 37s - loss: 0.3243 - accuracy: 0.8621 - val_loss: 0.3563 - val_accuracy: 0.8492
# Epoch 99/100
# 55/55 - 36s - loss: 0.3335 - accuracy: 0.8589 - val_loss: 0.3619 - val_accuracy: 0.8447
# Epoch 100/100
# 55/55 - 36s - loss: 0.3324 - accuracy: 0.8604 - val_loss: 0.3519 - val_accuracy: 0.8502

# %%
model.save("firstModel.h5")

# %%
model=Sequential()
model.add(Conv2D(filters=32,kernel_size=(4,4),input_shape=(50,50,3),activation='relu'))
model.add(MaxPool2D(pool_size=(2,2)))

model.add(MaxPool2D(pool_size=(2,2)))
model.add(Dropout(0.25))

model.add(Conv2D(filters=32,kernel_size=(4,4),activation='relu'))
model.add(MaxPool2D(pool_size=(2,2)))

model.add(MaxPool2D(pool_size=(2,2), strides=(2,2)))
model.add(Dropout(0.25))

model.add(Flatten())

model.add(Dense(128,activation='relu'))
model.add(Dense(1,activation='sigmoid'))

model.compile(loss = 'binary_crossentropy', optimizer ='adam', metrics= ['accuracy'])


# model.summary()

# %%
epochs = 50  
batch_size = 250

history = model.fit(
    x_train, y_train,
    validation_data=(x_test, y_test),
    epochs= epochs,
    verbose = 2,
    batch_size=batch_size
    )
# Out:
# Epoch 1/50
# 56/56 - 51s - loss: 0.4553 - accuracy: 0.7926 - val_loss: 0.5236 - val_accuracy: 0.8052
# Epoch 2/50
# 56/56 - 47s - loss: 0.4369 - accuracy: 0.8049 - val_loss: 0.5216 - val_accuracy: 0.7953
# Epoch 3/50
# 56/56 - 48s - loss: 0.4309 - accuracy: 0.8087 - val_loss: 0.4520 - val_accuracy: 0.8057
# Epoch 4/50
# 56/56 - 54s - loss: 0.4204 - accuracy: 0.8164 - val_loss: 0.4714 - val_accuracy: 0.8000
# Epoch 5/50
# 56/56 - 46s - loss: 0.4100 - accuracy: 0.8200 - val_loss: 0.4219 - val_accuracy: 0.8265
# Epoch 6/50
# 56/56 - 42s - loss: 0.4139 - accuracy: 0.8170 - val_loss: 0.4183 - val_accuracy: 0.8278
# Epoch 7/50
# 56/56 - 48s - loss: 0.4084 - accuracy: 0.8199 - val_loss: 0.4574 - val_accuracy: 0.8093
# Epoch 8/50
# 56/56 - 37s - loss: 0.4033 - accuracy: 0.8230 - val_loss: 0.4467 - val_accuracy: 0.8125
# Epoch 9/50
# 56/56 - 40s - loss: 0.4047 - accuracy: 0.8244 - val_loss: 0.4066 - val_accuracy: 0.8308
# Epoch 10/50
# 56/56 - 38s - loss: 0.4147 - accuracy: 0.8174 - val_loss: 0.4107 - val_accuracy: 0.8338
# Epoch 11/50
# 56/56 - 39s - loss: 0.3954 - accuracy: 0.8289 - val_loss: 0.4297 - val_accuracy: 0.8282
# Epoch 12/50
# 56/56 - 36s - loss: 0.3988 - accuracy: 0.8256 - val_loss: 0.4032 - val_accuracy: 0.8360
# Epoch 13/50
# 56/56 - 37s - loss: 0.3934 - accuracy: 0.8300 - val_loss: 0.4368 - val_accuracy: 0.8148
# Epoch 14/50
# 56/56 - 35s - loss: 0.3929 - accuracy: 0.8287 - val_loss: 0.4122 - val_accuracy: 0.8293
# Epoch 15/50
# 56/56 - 36s - loss: 0.3902 - accuracy: 0.8309 - val_loss: 0.4346 - val_accuracy: 0.8262
# Epoch 16/50
# 56/56 - 34s - loss: 0.3926 - accuracy: 0.8318 - val_loss: 0.4339 - val_accuracy: 0.8182
# Epoch 17/50
# 56/56 - 35s - loss: 0.3938 - accuracy: 0.8309 - val_loss: 0.4557 - val_accuracy: 0.8125
# Epoch 18/50
# 56/56 - 35s - loss: 0.3860 - accuracy: 0.8340 - val_loss: 0.3960 - val_accuracy: 0.8383
# Epoch 19/50
# 56/56 - 36s - loss: 0.3863 - accuracy: 0.8340 - val_loss: 0.4458 - val_accuracy: 0.8158
# Epoch 20/50
# 56/56 - 35s - loss: 0.3820 - accuracy: 0.8334 - val_loss: 0.3975 - val_accuracy: 0.8365
# Epoch 21/50
# 56/56 - 40s - loss: 0.3901 - accuracy: 0.8321 - val_loss: 0.3890 - val_accuracy: 0.8428
# Epoch 22/50
# 56/56 - 52s - loss: 0.3821 - accuracy: 0.8328 - val_loss: 0.3817 - val_accuracy: 0.8448
# Epoch 23/50
# 56/56 - 44s - loss: 0.3864 - accuracy: 0.8349 - val_loss: 0.3957 - val_accuracy: 0.8428
# Epoch 24/50
# 56/56 - 44s - loss: 0.3832 - accuracy: 0.8336 - val_loss: 0.4030 - val_accuracy: 0.8373
# Epoch 25/50
# 56/56 - 45s - loss: 0.3814 - accuracy: 0.8363 - val_loss: 0.3754 - val_accuracy: 0.8457
# Epoch 26/50
# 56/56 - 42s - loss: 0.3750 - accuracy: 0.8379 - val_loss: 0.4071 - val_accuracy: 0.8417
# Epoch 27/50
# 56/56 - 47s - loss: 0.3746 - accuracy: 0.8377 - val_loss: 0.4908 - val_accuracy: 0.7763
# Epoch 28/50
# 56/56 - 44s - loss: 0.3725 - accuracy: 0.8383 - val_loss: 0.3983 - val_accuracy: 0.8407
# Epoch 29/50
# 56/56 - 43s - loss: 0.3756 - accuracy: 0.8374 - val_loss: 0.4582 - val_accuracy: 0.8025
# Epoch 30/50
# 56/56 - 49s - loss: 0.3773 - accuracy: 0.8356 - val_loss: 0.4196 - val_accuracy: 0.8278
# Epoch 31/50
# 56/56 - 43s - loss: 0.3684 - accuracy: 0.8410 - val_loss: 0.4333 - val_accuracy: 0.8200
# Epoch 32/50
# 56/56 - 39s - loss: 0.3724 - accuracy: 0.8404 - val_loss: 0.4409 - val_accuracy: 0.8083
# Epoch 33/50
# 56/56 - 39s - loss: 0.3673 - accuracy: 0.8439 - val_loss: 0.4215 - val_accuracy: 0.8243
# Epoch 34/50
# 56/56 - 40s - loss: 0.3709 - accuracy: 0.8411 - val_loss: 0.4373 - val_accuracy: 0.8108
# Epoch 35/50
# 56/56 - 41s - loss: 0.3711 - accuracy: 0.8397 - val_loss: 0.3962 - val_accuracy: 0.8425
# Epoch 36/50
# 56/56 - 44s - loss: 0.3721 - accuracy: 0.8433 - val_loss: 0.3885 - val_accuracy: 0.8467
# Epoch 37/50
# 56/56 - 37s - loss: 0.3676 - accuracy: 0.8401 - val_loss: 0.4161 - val_accuracy: 0.8262
# Epoch 38/50
# 56/56 - 38s - loss: 0.3654 - accuracy: 0.8431 - val_loss: 0.4431 - val_accuracy: 0.8100
# Epoch 39/50
# 56/56 - 38s - loss: 0.3668 - accuracy: 0.8436 - val_loss: 0.3883 - val_accuracy: 0.8388
# Epoch 40/50
# 56/56 - 37s - loss: 0.3621 - accuracy: 0.8446 - val_loss: 0.3986 - val_accuracy: 0.8387
# Epoch 41/50
# 56/56 - 40s - loss: 0.3721 - accuracy: 0.8420 - val_loss: 0.4089 - val_accuracy: 0.8335
# Epoch 42/50
# 56/56 - 38s - loss: 0.3653 - accuracy: 0.8416 - val_loss: 0.4547 - val_accuracy: 0.7925
# Epoch 43/50
# 56/56 - 38s - loss: 0.3669 - accuracy: 0.8421 - val_loss: 0.4276 - val_accuracy: 0.8135
# Epoch 44/50
# 56/56 - 37s - loss: 0.3613 - accuracy: 0.8471 - val_loss: 0.4544 - val_accuracy: 0.8000
# Epoch 45/50
# 56/56 - 40s - loss: 0.3608 - accuracy: 0.8458 - val_loss: 0.3665 - val_accuracy: 0.8498
# Epoch 46/50
# 56/56 - 37s - loss: 0.3553 - accuracy: 0.8469 - val_loss: 0.3614 - val_accuracy: 0.8497
# Epoch 47/50
# 56/56 - 37s - loss: 0.3608 - accuracy: 0.8451 - val_loss: 0.3980 - val_accuracy: 0.8320
# Epoch 48/50
# 56/56 - 44s - loss: 0.3632 - accuracy: 0.8454 - val_loss: 0.4036 - val_accuracy: 0.8375
# Epoch 49/50
# 56/56 - 37s - loss: 0.3619 - accuracy: 0.8429 - val_loss: 0.4356 - val_accuracy: 0.8053
# Epoch 50/50
# 56/56 - 39s - loss: 0.3579 - accuracy: 0.8451 - val_loss: 0.4075 - val_accuracy: 0.8303

# %%
model = Sequential()
model.add(Dense(128, input_dim=8, activation='relu'))
model.add(Dense(8, activation='relu'))
model.add(Dense(1, activation='sigmoid'))
# compile the keras model
model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])
# fit the keras model on the dataset
# model.fit(X, y, epochs=150, batch_size=10)

history = model.fit(
    x_train, y_train,
    validation_data=(x_test, y_test),
    epochs= epochs,
    verbose = 2,
    batch_size=batch_size
    )
